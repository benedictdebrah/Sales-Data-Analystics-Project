# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading dataset
df=pd.read_csv("sales.csv")

# %%
#an overview of the dataset
df.head()
# Out:
#   product_code customer_code market_code  order_date  sales_qty  sales_amount  \
# 0      Prod001        Cus001     Mark001  2017-10-10        100         41241
# 1      Prod001        Cus002     Mark002  2018-05-08          3            -1
# 2      Prod002        Cus003     Mark003  2018-04-06          1           875
# 3      Prod002        Cus003     Mark003  2018-04-11          1           583
# 4      Prod002        Cus004     Mark003  2018-06-18          6          7176
#
#   currency product_code.1 product_type markets_code markets_name     zone  \
# 0      INR        Prod001  Own Brand\r      Mark001      Chennai    South
# 1      INR        Prod001  Own Brand\r      Mark002       Mumbai  Central
# 2      INR        Prod002  Own Brand\r      Mark003    Ahmedabad    North
# 3      INR        Prod002  Own Brand\r      Mark003    Ahmedabad    North
# 4      INR        Prod002  Own Brand\r      Mark003    Ahmedabad    North
#
#   customer_code.1    custmer_name   customer_type        date     cy_date  \
# 0          Cus001    Surge Stores  Brick & Mortar  2017-10-10  2017-10-01
# 1          Cus002    Nomad Stores  Brick & Mortar  2018-05-08  2018-05-01
# 2          Cus003    Excel Stores  Brick & Mortar  2018-04-06  2018-04-01
# 3          Cus003    Excel Stores  Brick & Mortar  2018-04-11  2018-04-01
# 4          Cus004  Surface Stores  Brick & Mortar  2018-06-18  2018-06-01
#
#    year month_name date_yy_mmm
# 0  2017    October    17-Oct\r
# 1  2018        May    18-May\r
# 2  2018      April    18-Apr\r
# 3  2018      April    18-Apr\r
# 4  2018       June    18-Jun\r

# %%
#info about dataset
print(f"Shape of data: {df.shape}")
print(f"Number of missing values in the data:\
{df.isnull().sum().sum()}")
# Out:
# Shape of data: (1000, 20)
# Number of missing values in the data:0

# %%
df.dtypes
# Out:
# product_code       object
# customer_code      object
# market_code        object
# order_date         object
# sales_qty           int64
# sales_amount        int64
# currency           object
# product_code.1     object
# product_type       object
# markets_code       object
# markets_name       object
# zone               object
# customer_code.1    object
# custmer_name       object
# customer_type      object
# date               object
# cy_date            object
# year                int64
# month_name         object
# date_yy_mmm        object
# dtype: object

# %% [markdown]
# #Data cleaning

# %%
df.columns
# Out:
# Index(['product_code', 'customer_code', 'market_code', 'order_date',
#        'sales_qty', 'sales_amount', 'currency', 'product_code.1',
#        'product_type', 'markets_code', 'markets_name', 'zone',
#        'customer_code.1', 'custmer_name', 'customer_type', 'date', 'cy_date',
#        'year', 'month_name', 'date_yy_mmm'],
#       dtype='object')

# %%
#will drop this column because its duplicated and doesn't look like a date actually
df['date_yy_mmm'].unique()
# Out:
# array(['17-Oct\r', '18-May\r', '18-Apr\r', '18-Jun\r', '17-Nov\r',
#        '17-Dec\r', '18-Aug\r', '18-Jul\r', '19-Jun\r', '19-Jul\r',
#        '19-Aug\r', '19-Sep\r', '18-Jan\r', '18-Feb\r', '18-Sep\r',
#        '18-Nov\r', '18-Dec\r', '19-Jan\r', '19-Feb\r', '19-Mar\r',
#        '19-Apr\r', '19-May\r', '19-Oct\r', '19-Nov\r', '19-Dec\r',
#        '20-Jan\r', '20-Feb\r', '20-Mar\r', '20-Apr\r', '20-May\r',
#        '18-Oct\r', '18-Mar\r', '20-Jun\r'], dtype=object)

# %%
df.drop(['product_code.1', 'customer_code.1','date','markets_code','date_yy_mmm','cy_date'],axis=1,inplace=True)

# %%
df
# Out:
#     product_code customer_code market_code  order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001  2017-10-10        100
# 1        Prod001        Cus002     Mark002  2018-05-08          3
# 2        Prod002        Cus003     Mark003  2018-04-06          1
# 3        Prod002        Cus003     Mark003  2018-04-11          1
# 4        Prod002        Cus004     Mark003  2018-06-18          6
# ..           ...           ...         ...         ...        ...
# 995      Prod018        Cus016     Mark002  2019-02-15         62
# 996      Prod018        Cus022     Mark002  2019-02-15          4
# 997      Prod018        Cus022     Mark002  2019-02-15         13
# 998      Prod018        Cus022     Mark002  2019-02-18          3
# 999      Prod018        Cus025     Mark002  2019-02-18          8
#
#      sales_amount currency product_type markets_name     zone  \
# 0           41241      INR  Own Brand\r      Chennai    South
# 1              -1      INR  Own Brand\r       Mumbai  Central
# 2             875      INR  Own Brand\r    Ahmedabad    North
# 3             583      INR  Own Brand\r    Ahmedabad    North
# 4            7176      INR  Own Brand\r    Ahmedabad    North
# ..            ...      ...          ...          ...      ...
# 995        129546    INR\r  Own Brand\r       Mumbai  Central
# 996          9190    INR\r  Own Brand\r       Mumbai  Central
# 997         28269    INR\r  Own Brand\r       Mumbai  Central
# 998          6125    INR\r  Own Brand\r       Mumbai  Central
# 999         17495    INR\r  Own Brand\r       Mumbai  Central
#
#            custmer_name   customer_type  year month_name
# 0          Surge Stores  Brick & Mortar  2017    October
# 1          Nomad Stores  Brick & Mortar  2018        May
# 2          Excel Stores  Brick & Mortar  2018      April
# 3          Excel Stores  Brick & Mortar  2018      April
# 4        Surface Stores  Brick & Mortar  2018       June
# ..                  ...             ...   ...        ...
# 995        Logic Stores  Brick & Mortar  2019   February
# 996  Electricalslytical      E-Commerce  2019   February
# 997  Electricalslytical      E-Commerce  2019   February
# 998  Electricalslytical      E-Commerce  2019   February
# 999                Path      E-Commerce  2019   February
#
# [1000 rows x 14 columns]

# %%
df['markets_name'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Ahmedabad', 'Delhi NCR', 'Kanpur',
#        'Bengaluru', 'Bhopal', 'Lucknow'], dtype=object)

# %%
df['currency'].unique()
# Out:
# array(['INR', 'USD', 'INR\r', 'USD\r'], dtype=object)

# %%
#changing datatype
df[['sales_amount','sales_qty']].astype(int)
df['order_date']=pd.to_datetime(df['order_date'])
df[['year','month_name']].astype(str)
df[['currency','product_type','markets_name','zone','custmer_name','customer_type']].astype(str)
# Out:
#     currency product_type markets_name     zone        custmer_name  \
# 0        INR  Own Brand\r      Chennai    South        Surge Stores
# 1        INR  Own Brand\r       Mumbai  Central        Nomad Stores
# 2        INR  Own Brand\r    Ahmedabad    North        Excel Stores
# 3        INR  Own Brand\r    Ahmedabad    North        Excel Stores
# 4        INR  Own Brand\r    Ahmedabad    North      Surface Stores
# ..       ...          ...          ...      ...                 ...
# 995    INR\r  Own Brand\r       Mumbai  Central        Logic Stores
# 996    INR\r  Own Brand\r       Mumbai  Central  Electricalslytical
# 997    INR\r  Own Brand\r       Mumbai  Central  Electricalslytical
# 998    INR\r  Own Brand\r       Mumbai  Central  Electricalslytical
# 999    INR\r  Own Brand\r       Mumbai  Central                Path
#
#       customer_type
# 0    Brick & Mortar
# 1    Brick & Mortar
# 2    Brick & Mortar
# 3    Brick & Mortar
# 4    Brick & Mortar
# ..              ...
# 995  Brick & Mortar
# 996      E-Commerce
# 997      E-Commerce
# 998      E-Commerce
# 999      E-Commerce
#
# [1000 rows x 6 columns]

# %%
#removing "\"
df['currency']=df['currency'].replace('INR\r','INR')
df['currency']=df['currency'].replace('USD\r','USD')
df['product_type']=df['product_type'].replace('Own Brand\r','Own Brand')

# %%
#concatenate year and month column
df['month_year']=df['month_name'].map(str) +" "+ df['year'].map(str)

# %%
df
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 1        Prod001        Cus002     Mark002 2018-05-08          3
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency product_type markets_name     zone  \
# 0           41241      INR    Own Brand      Chennai    South
# 1              -1      INR    Own Brand       Mumbai  Central
# 2             875      INR    Own Brand    Ahmedabad    North
# 3             583      INR    Own Brand    Ahmedabad    North
# 4            7176      INR    Own Brand    Ahmedabad    North
# ..            ...      ...          ...          ...      ...
# 995        129546      INR    Own Brand       Mumbai  Central
# 996          9190      INR    Own Brand       Mumbai  Central
# 997         28269      INR    Own Brand       Mumbai  Central
# 998          6125      INR    Own Brand       Mumbai  Central
# 999         17495      INR    Own Brand       Mumbai  Central
#
#            custmer_name   customer_type  year month_name     month_year
# 0          Surge Stores  Brick & Mortar  2017    October   October 2017
# 1          Nomad Stores  Brick & Mortar  2018        May       May 2018
# 2          Excel Stores  Brick & Mortar  2018      April     April 2018
# 3          Excel Stores  Brick & Mortar  2018      April     April 2018
# 4        Surface Stores  Brick & Mortar  2018       June      June 2018
# ..                  ...             ...   ...        ...            ...
# 995        Logic Stores  Brick & Mortar  2019   February  February 2019
# 996  Electricalslytical      E-Commerce  2019   February  February 2019
# 997  Electricalslytical      E-Commerce  2019   February  February 2019
# 998  Electricalslytical      E-Commerce  2019   February  February 2019
# 999                Path      E-Commerce  2019   February  February 2019
#
# [1000 rows x 15 columns]

# %%
#checked the recent changes
df['product_type'].unique()
# Out:
# array(['Own Brand'], dtype=object)

# %%
#since product_type we know its "our brand " we can drop it
df.drop('product_type',axis=1,inplace=True)

# %%
df
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 1        Prod001        Cus002     Mark002 2018-05-08          3
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency markets_name     zone        custmer_name  \
# 0           41241      INR      Chennai    South        Surge Stores
# 1              -1      INR       Mumbai  Central        Nomad Stores
# 2             875      INR    Ahmedabad    North        Excel Stores
# 3             583      INR    Ahmedabad    North        Excel Stores
# 4            7176      INR    Ahmedabad    North      Surface Stores
# ..            ...      ...          ...      ...                 ...
# 995        129546      INR       Mumbai  Central        Logic Stores
# 996          9190      INR       Mumbai  Central  Electricalslytical
# 997         28269      INR       Mumbai  Central  Electricalslytical
# 998          6125      INR       Mumbai  Central  Electricalslytical
# 999         17495      INR       Mumbai  Central                Path
#
#       customer_type  year month_name     month_year
# 0    Brick & Mortar  2017    October   October 2017
# 1    Brick & Mortar  2018        May       May 2018
# 2    Brick & Mortar  2018      April     April 2018
# 3    Brick & Mortar  2018      April     April 2018
# 4    Brick & Mortar  2018       June      June 2018
# ..              ...   ...        ...            ...
# 995  Brick & Mortar  2019   February  February 2019
# 996      E-Commerce  2019   February  February 2019
# 997      E-Commerce  2019   February  February 2019
# 998      E-Commerce  2019   February  February 2019
# 999      E-Commerce  2019   February  February 2019
#
# [1000 rows x 14 columns]

# %%
df.dtypes
# Out:
# product_code             object
# customer_code            object
# market_code              object
# order_date       datetime64[ns]
# sales_qty                 int64
# sales_amount              int64
# currency                 object
# markets_name             object
# zone                     object
# custmer_name             object
# customer_type            object
# year                      int64
# month_name               object
# month_year               object
# dtype: object

# %%
df
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 1        Prod001        Cus002     Mark002 2018-05-08          3
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency markets_name     zone        custmer_name  \
# 0           41241      INR      Chennai    South        Surge Stores
# 1              -1      INR       Mumbai  Central        Nomad Stores
# 2             875      INR    Ahmedabad    North        Excel Stores
# 3             583      INR    Ahmedabad    North        Excel Stores
# 4            7176      INR    Ahmedabad    North      Surface Stores
# ..            ...      ...          ...      ...                 ...
# 995        129546      INR       Mumbai  Central        Logic Stores
# 996          9190      INR       Mumbai  Central  Electricalslytical
# 997         28269      INR       Mumbai  Central  Electricalslytical
# 998          6125      INR       Mumbai  Central  Electricalslytical
# 999         17495      INR       Mumbai  Central                Path
#
#       customer_type  year month_name     month_year
# 0    Brick & Mortar  2017    October   October 2017
# 1    Brick & Mortar  2018        May       May 2018
# 2    Brick & Mortar  2018      April     April 2018
# 3    Brick & Mortar  2018      April     April 2018
# 4    Brick & Mortar  2018       June      June 2018
# ..              ...   ...        ...            ...
# 995  Brick & Mortar  2019   February  February 2019
# 996      E-Commerce  2019   February  February 2019
# 997      E-Commerce  2019   February  February 2019
# 998      E-Commerce  2019   February  February 2019
# 999      E-Commerce  2019   February  February 2019
#
# [1000 rows x 14 columns]

# %%
#we cannot have a sales of -1 and 0 ..we cant give items for free ..lol so we have to  filter them out
df['sales_amount'].unique()
# Out:
# array([ 41241,     -1,    875,    583,   7176,    500,    250,  21412,
#         19213, 170185, 101194,   9426,    218,   3093,  30306,  52319,
#        126296, 107500,    273,   3574,  23403,  76329,   4542,  16579,
#        105301,    185,    556,    551,    167,    333,    833,   1000,
#          1833,  10657,    157,    315,    630,    472,    787,   1102,
#           944,   1417,   1259,   1574,  66111,   1884,   2574,   3773,
#          2042,    417,    310,    208,    620,    829,   2694,    102,
#           528,    380,    560,   1116,    657,   6218,   2426,  15278,
#          3032,   3194,    912,   1824,    458,   4444,   2667,  19171,
#          1370,   1333,    597,   8889,   1778,   9130,    602,   3227,
#           449,   9880,    301,   7954,   2153,   5306,   1801,   2699,
#          1616,   2245,      0,    903,   3778,    537,   4051,  14815,
#          4495,   2690,  23866,    898,   4940,   3602,   3583,   4954,
#          1889,   1352,    444,    505,   1514,   2023,  37889,    593,
#          2389,   1194,  13736,  17472,   2986,    796,  26722,   3185,
#          5574,   1593,    514,   4759,   1190,   4106,   5949,   1028,
#          2056,   1542,    611,   4778,  10352,  29648, 143560,   6204,
#           495,  25130,    986,  23898,    296,    356,   1977,   8375,
#          7171,  77931,  40704,  47074,   4028,  30167,   1968,   1366,
#          6713,  27708,   7644,  10972,   1218,  13407,    245, 115481,
#         78986, 245546, 162292,    412,   7981,  27505, 145921,    546,
#         28167,  32764,   6648,  40366,   4273,    949,    477,  70356,
#          6528,  19727,   3324, 103889,  18167, 106560,  90130,  54079,
#        153815,    306, 132519, 152833,  10144,   8991,   1708,  79676,
#           486,  25356,  17519,   6338,   9190,   8384,   4889,   3495,
#          2065,   1380,  11870,  12574,   2796,   2792,  68898,   6991,
#           681,  44782,  26537,   3444,   4190,   2755,  18852,   6287,
#         41199,   1356,   5588,  32125,  13778,   4194,   2713,  65648,
#         48231,  16065,   1398,  20255,    699,  12014,  43537,  65310,
#         21769,   2176,  17222,  48917,  26333,    347,   6125,  10824,
#          3065,   3843,   6130,  10884,    343,    690,  12250,   4130,
#         32653,  37690,   3056,  34157,  20023,  28269,   1176,  56537,
#         16491,  14134,  40046,    338,  14407,  25912,  52667,   4319,
#        251903,   1440,  21199,    361,  55356,  29444,   2162,   7065,
#         55977,  10495,  45935,  34986,  36509,  27991,  15315,  45481,
#        140157,  17495,  59477,   1079,    676,  24792,  11519,   1019,
#           722,  17463, 169606,   6995,   1745,  38486,  52481,  35963,
#         33690,  38060,  23394,  20991,  43991,  77870,  13264,  36014,
#        121509,  72028,  46444, 122898,  19556,  38407,  24491, 167935,
#        226963, 141343,  62977,  56532,  17458,  27565,  38065,  41898,
#        104958, 113074, 115921,  18375,  41981,  31421,  71231,  24500,
#         55167,  13995, 129546], dtype=int64)

# %%
df
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 1        Prod001        Cus002     Mark002 2018-05-08          3
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency markets_name     zone        custmer_name  \
# 0           41241      INR      Chennai    South        Surge Stores
# 1              -1      INR       Mumbai  Central        Nomad Stores
# 2             875      INR    Ahmedabad    North        Excel Stores
# 3             583      INR    Ahmedabad    North        Excel Stores
# 4            7176      INR    Ahmedabad    North      Surface Stores
# ..            ...      ...          ...      ...                 ...
# 995        129546      INR       Mumbai  Central        Logic Stores
# 996          9190      INR       Mumbai  Central  Electricalslytical
# 997         28269      INR       Mumbai  Central  Electricalslytical
# 998          6125      INR       Mumbai  Central  Electricalslytical
# 999         17495      INR       Mumbai  Central                Path
#
#       customer_type  year month_name     month_year
# 0    Brick & Mortar  2017    October   October 2017
# 1    Brick & Mortar  2018        May       May 2018
# 2    Brick & Mortar  2018      April     April 2018
# 3    Brick & Mortar  2018      April     April 2018
# 4    Brick & Mortar  2018       June      June 2018
# ..              ...   ...        ...            ...
# 995  Brick & Mortar  2019   February  February 2019
# 996      E-Commerce  2019   February  February 2019
# 997      E-Commerce  2019   February  February 2019
# 998      E-Commerce  2019   February  February 2019
# 999      E-Commerce  2019   February  February 2019
#
# [1000 rows x 14 columns]

# %%
#filtered
df[df['sales_amount'] > 0]
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# 5        Prod003        Cus005     Mark004 2017-11-20         59
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency markets_name     zone        custmer_name  \
# 0           41241      INR      Chennai    South        Surge Stores
# 2             875      INR    Ahmedabad    North        Excel Stores
# 3             583      INR    Ahmedabad    North        Excel Stores
# 4            7176      INR    Ahmedabad    North      Surface Stores
# 5             500      USD    Delhi NCR    North      Premium Stores
# ..            ...      ...          ...      ...                 ...
# 995        129546      INR       Mumbai  Central        Logic Stores
# 996          9190      INR       Mumbai  Central  Electricalslytical
# 997         28269      INR       Mumbai  Central  Electricalslytical
# 998          6125      INR       Mumbai  Central  Electricalslytical
# 999         17495      INR       Mumbai  Central                Path
#
#       customer_type  year month_name     month_year
# 0    Brick & Mortar  2017    October   October 2017
# 2    Brick & Mortar  2018      April     April 2018
# 3    Brick & Mortar  2018      April     April 2018
# 4    Brick & Mortar  2018       June      June 2018
# 5    Brick & Mortar  2017   November  November 2017
# ..              ...   ...        ...            ...
# 995  Brick & Mortar  2019   February  February 2019
# 996      E-Commerce  2019   February  February 2019
# 997      E-Commerce  2019   February  February 2019
# 998      E-Commerce  2019   February  February 2019
# 999      E-Commerce  2019   February  February 2019
#
# [991 rows x 14 columns]

# %%
df['currency'].unique()
# Out:
# array(['INR', 'USD'], dtype=object)

# %%
#making currency in local currency INR..exhange rate used here  to create a normalize valuea
inr = {'INR':1, 'USD':74.60}
df['nomalized_sales'] = df['currency'].map(inr) * df['sales_amount']
df
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 0        Prod001        Cus001     Mark001 2017-10-10        100
# 1        Prod001        Cus002     Mark002 2018-05-08          3
# 2        Prod002        Cus003     Mark003 2018-04-06          1
# 3        Prod002        Cus003     Mark003 2018-04-11          1
# 4        Prod002        Cus004     Mark003 2018-06-18          6
# ..           ...           ...         ...        ...        ...
# 995      Prod018        Cus016     Mark002 2019-02-15         62
# 996      Prod018        Cus022     Mark002 2019-02-15          4
# 997      Prod018        Cus022     Mark002 2019-02-15         13
# 998      Prod018        Cus022     Mark002 2019-02-18          3
# 999      Prod018        Cus025     Mark002 2019-02-18          8
#
#      sales_amount currency markets_name     zone        custmer_name  \
# 0           41241      INR      Chennai    South        Surge Stores
# 1              -1      INR       Mumbai  Central        Nomad Stores
# 2             875      INR    Ahmedabad    North        Excel Stores
# 3             583      INR    Ahmedabad    North        Excel Stores
# 4            7176      INR    Ahmedabad    North      Surface Stores
# ..            ...      ...          ...      ...                 ...
# 995        129546      INR       Mumbai  Central        Logic Stores
# 996          9190      INR       Mumbai  Central  Electricalslytical
# 997         28269      INR       Mumbai  Central  Electricalslytical
# 998          6125      INR       Mumbai  Central  Electricalslytical
# 999         17495      INR       Mumbai  Central                Path
#
#       customer_type  year month_name     month_year  nomalized_sales
# 0    Brick & Mortar  2017    October   October 2017          41241.0
# 1    Brick & Mortar  2018        May       May 2018             -1.0
# 2    Brick & Mortar  2018      April     April 2018            875.0
# 3    Brick & Mortar  2018      April     April 2018            583.0
# 4    Brick & Mortar  2018       June      June 2018           7176.0
# ..              ...   ...        ...            ...              ...
# 995  Brick & Mortar  2019   February  February 2019         129546.0
# 996      E-Commerce  2019   February  February 2019           9190.0
# 997      E-Commerce  2019   February  February 2019          28269.0
# 998      E-Commerce  2019   February  February 2019           6125.0
# 999      E-Commerce  2019   February  February 2019          17495.0
#
# [1000 rows x 15 columns]

# %%
#checking to see whether fx change worked
df[df['currency']=="USD"]
# Out:
#     product_code customer_code market_code order_date  sales_qty  \
# 5        Prod003        Cus005     Mark004 2017-11-20         59
# 6        Prod003        Cus005     Mark004 2017-11-22         36
# 286      Prod003        Cus005     Mark004 2017-11-20         59
# 287      Prod003        Cus005     Mark004 2017-11-22         36
#
#      sales_amount currency markets_name   zone    custmer_name  \
# 5             500      USD    Delhi NCR  North  Premium Stores
# 6             250      USD    Delhi NCR  North  Premium Stores
# 286           500      USD    Delhi NCR  North  Premium Stores
# 287           250      USD    Delhi NCR  North  Premium Stores
#
#       customer_type  year month_name     month_year  nomalized_sales
# 5    Brick & Mortar  2017   November  November 2017          37300.0
# 6    Brick & Mortar  2017   November  November 2017          18650.0
# 286  Brick & Mortar  2017   November  November 2017          37300.0
# 287  Brick & Mortar  2017   November  November 2017          18650.0

# %%
#creating cleaned dataset
#df.to_csv('cleaned_sales.csv',index=False)

# %% [markdown]
# Visualizing dataset based On Questions

# %% [markdown]
# # Sales Breakdown By Cities(markets)

# %%
plt.figure(figsize=(10,7))
sns.set()
sns.barplot(x='year', y='sales_qty',data=df,hue='markets_name')
plt.xlabel('Years W.R.T Markets')
plt.ylabel('Number Of Sales')
plt.show()

# %% [markdown]
# # Sales Breakdown with month

# %%
plt.figure(figsize=(15,8))

sns.barplot(x='month_name', y='sales_qty',data=df,hue='year')
plt.xlabel('Months')
plt.ylabel('Number Of Sales')
plt.show()

# %% [markdown]
# from the look of 2018 to 2020 there is decline in sales

# %% [markdown]
# # so now we can observe that sales are declining. And the question is ..why are sales declining ?

# %% [markdown]
# 1. Is it because we have a competing company ?
# 2. Is our customer care not good enough ?
# 3. Has our product lost value ?
# 3. Are our products expensive as  compared to our competing companies ?
# 4. Should we start give discounts?

# %% [markdown]
# # Revenue Breakdown

# %%
plt.figure(figsize=(15,8))

plt.bar(df['year'], df['nomalized_sales'])
plt.xlabel('Years')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# # Revenue also declined

# %% [markdown]
# -Its obvious that when sales decline revenue will also decline but
#
# 1. what measures did we implement for the high revenue in 2018?

# %%
plt.figure(figsize=(15,8))

plt.bar(df['year'], df['sales_qty'])
plt.xlabel('Years')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# To Navigate Dashboard:
#     click on this link:
